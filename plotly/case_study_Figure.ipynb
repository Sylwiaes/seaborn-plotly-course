# %% [markdown]
# <a href="https://colab.research.google.com/github/Sylwiaes/seaborn-plotly-course/blob/main/plotly/case_study_Figure.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def fetch_financial_data(company='AMZN'):
    """
    This function fetch stock market quotations.
    """
    import pandas_datareader.data as web
    return web.DataReader(name=company, data_source='stooq')

df_amzn = fetch_financial_data(company='AMZN')
df_aapl = fetch_financial_data(company='AAPL')
df_msft = fetch_financial_data(company='MSFT')
df_nflx = fetch_financial_data(company='NFLX')
df_twtr = fetch_financial_data(company='TWTR')

# %%
df_amzn.head(2)
# Out:
#                  Open       High      Low    Close   Volume
# Date
# 2021-05-21  3250.0000  3256.6946  3197.01  3203.08  4104882
# 2021-05-20  3244.4042  3259.6799  3236.18  3247.68  2633192

# %%
import pandas as pd

df = pd.concat([df_amzn.Close, df_aapl.Close, df_msft.Close, df_nflx.Close, df_twtr.Close], axis=1, join='inner')  
#stosujemy funkcję concat, aby połączyć dane i przekazujemy listę danych
df.columns = ['amazon', 'apple', 'microsoft', 'netflix', 'twitter']
df = df.reset_index()
df.head()
# Out:
#         Date   amazon   apple  microsoft  netflix  twitter
# 0 2021-05-21  3203.08  125.43     245.17   497.89    54.45
# 1 2021-05-20  3247.68  127.31     246.48   501.67    54.71
# 2 2021-05-19  3231.80  124.69     243.12   487.70    52.92
# 3 2021-05-18  3232.28  124.85     243.08   486.28    53.19
# 4 2021-05-17  3270.39  126.27     245.18   488.94    52.60

# %%
df.describe()
# Out:
#             amazon        apple    microsoft      netflix      twitter
# count  1259.000000  1259.000000  1259.000000  1259.000000  1259.000000
# mean   1759.398940    58.649744   122.079147   305.638705    31.630373
# std     811.525901    32.420412    59.315158   136.035281    12.962818
# min     691.360000    21.533000    44.720000    85.330000    14.020000
# 25%     987.745000    37.067500    69.689500   179.210000    18.930000
# 50%    1720.260000    46.146000   104.800000   317.940000    31.350000
# 75%    1994.655000    71.421500   162.350000   380.630000    38.090000
# max    3531.450000   142.950000   261.970000   586.340000    77.630000

# %%
import plotly.graph_objects as go

trace0 = go.Scatter(x=df.Date, 
                    y=df.amazon,
                    name='Amazon')

trace1 = go.Scatter(x=df.Date, 
                    y=df.apple,
                    name='Apple')

trace2 = go.Scatter(x=df.Date, 
                    y=df.microsoft,
                    name='Microsoft')

trace3 = go.Scatter(x=df.Date, 
                    y=df.netflix,
                    name='Netflix')

trace4 = go.Scatter(x=df.Date, 
                    y=df.twitter,
                    name='Twitter')

data = [trace0, trace1, trace2, trace3, trace4]

layout = go.Layout(yaxis_type='log') #ustawiamy layout i w nim oś y jako logarytmiczną, aby mieć dane procentowe

fig = go.Figure(data=data, layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="d716100b-b643-4672-b262-02469352dad5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d716100b-b643-4672-b262-02469352dad5")) {
#                     Plotly.newPlot(
#                         'd716100b-b643-4672-b262-02469352dad5',
# ...

# %% [markdown]
# Druga metoda tworzenia wykresów

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(
    x=df.Date,
    y=df.amazon,
    name='Amazon'
))

fig.add_trace(go.Scatter(
    x=df.Date,
    y=df.apple,
    name='Apple'
))

fig.add_trace(go.Scatter(
    x=df.Date,
    y=df.microsoft,
    name='Microsoft'
))

fig.add_trace(go.Scatter(
    x=df.Date,
    y=df.netflix,
    name='Netflix'
))

fig.add_trace(go.Scatter(
    x=df.Date,
    y=df.twitter,
    name='Twitter'
))

fig.update_layout(yaxis_type='log')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="80d1282f-7886-4e29-87c7-18b475ba0fc3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("80d1282f-7886-4e29-87c7-18b475ba0fc3")) {
#                     Plotly.newPlot(
#                         '80d1282f-7886-4e29-87c7-18b475ba0fc3',
# ...

# %% [markdown]
# Zautomatyzowanie zapisu

# %%
data = [go.Scatter(x=df.Date, y=df[col], name=col) for col in df.columns[1:]]
layout = go.Layout(yaxis_type='log')
fig = go.Figure(data=data, layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="aab2c15a-465d-44d6-8697-e323b6ef0291" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("aab2c15a-465d-44d6-8697-e323b6ef0291")) {
#                     Plotly.newPlot(
#                         'aab2c15a-465d-44d6-8697-e323b6ef0291',
# ...
